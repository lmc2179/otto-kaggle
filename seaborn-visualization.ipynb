# %%
# %matplotlib inline
import seaborn as sns
import config
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
training_data = pd.read_csv(config.training_data_csv, index_col='id')
sns.set_palette("deep", desat=.6)
sns.set_context(rc={"figure.figsize": (8, 4)})
np.random.seed(9221999)
training_data.describe()
# Out:
#             feat_1        feat_2        feat_3        feat_4        feat_5  \
# count  61878.00000  61878.000000  61878.000000  61878.000000  61878.000000
# mean       0.38668      0.263066      0.901467      0.779081      0.071043
# std        1.52533      1.252073      2.934818      2.788005      0.438902
# min        0.00000      0.000000      0.000000      0.000000      0.000000
# 25%        0.00000      0.000000      0.000000      0.000000      0.000000
# 50%        0.00000      0.000000      0.000000      0.000000      0.000000
# 75%        0.00000      0.000000      0.000000      0.000000      0.000000
# max       61.00000     51.000000     64.000000     70.000000     19.000000
#
#              feat_6        feat_7        feat_8        feat_9       feat_10  \
# count  61878.000000  61878.000000  61878.000000  61878.000000  61878.000000
# mean       0.025696      0.193704      0.662433      1.011296      0.263906
# ...

# %%
training_data.hist(bins=100, figsize=(30,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7faf694edb70>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf66f36710>]], dtype=object)

# %%
sns.set(style="darkgrid")

rs = np.random.RandomState(33)

f, ax = plt.subplots(figsize=(30, 30))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.corrplot(training_data, annot=False, sig_stars=False,
             diag_names=False, cmap=cmap, ax=ax)
# f.tight_layout()

# %%
feature_columns = training_data.columns[:-1]
sns.violinplot(training_data[feature_columns])
